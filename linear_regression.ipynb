# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # read the dataset

# %%
df = pd.read_csv("archive (18).zip")

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %% [markdown]
# # sanity check for data

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.shape
# Out:
# (5000, 7)

# %% [markdown]
# # finding missing values

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %% [markdown]
# # finding duplicated value

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# renaming columns

# %%
df1 = df.rename(columns={'Avg. Area Income':'income','Avg. Area House Age':'house_Age','Avg. Area Number of Rooms':'no_rooms','Avg. Area Number of Bedrooms':'bedrooms','Area Population':'pop'})

# %%
df1.head(3)
# Out:
#          income  house_Age  no_rooms  bedrooms           pop         Price  \
# 0  79545.458574   5.682861  7.009188      4.09  23086.800503  1.059034e+06
# 1  79248.642455   6.002900  6.730821      3.09  40173.072174  1.505891e+06
# 2  61287.067179   5.865890  8.512727      5.13  36882.159400  1.058988e+06
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...

# %%
df1.columns
# Out:
# Index(['income', 'house_Age', 'no_rooms', 'bedrooms', 'pop', 'Price',
#        'Address'],
#       dtype='object')

# %% [markdown]
# # outlier detection

# %%
plt.boxplot(df1[['income', 'house_Age', 'no_rooms', 'bedrooms', 'pop']])
plt.show()

# %%
df2 = df1.drop('Address',axis = 1)

# %%
df2.clip(df2.quantile(0.2),df2.quantile(0.9),axis = 1,inplace = True)

# %% [markdown]
# # outlier removal

# %%
plt.boxplot(df2[['income', 'house_Age', 'no_rooms', 'bedrooms', 'pop']])
plt.show()

# %% [markdown]
# # eda

# %% [markdown]
# for i in df.select_dtypes(include="number").columns:
#     sns.histplot(data=df,x=i)
#     plt.show()

# %% [markdown]
# 1) uniform dist
# 2) binomial dist
# 3) bernouli's dist
# 4) normal dist
# 5) exponential dist

# %% [markdown]
# for i in df.select_dtypes(include="number").columns:
#     sns.scatterplot(data=df, x=i, y=df['Price'])
#     plt.show()

# %% [markdown]
# for i in df.select_dtypes(include="number").columns:
#     sns.barplot(data=df, x=i, y=df['Price'])
#     plt.show()

# %% [markdown]
# import matplotlib.pyplot as plt
# column_counts = df.select_dtypes(include='number').sum()
# plt.figure(figsize=(8, 8))
# plt.pie(column_counts, labels=column_counts.index, autopct='%1.1f%%', colors=plt.cm.tab10.colors)
# plt.title('Pie Chart of Dataset')
# plt.show()

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.preprocessing import Normalizer,RobustScaler

# %%
df1.columns
# Out:
# Index(['income', 'house_Age', 'no_rooms', 'bedrooms', 'pop', 'Price',
#        'Address'],
#       dtype='object')

# %%
x = df1[['income','house_Age','no_rooms','bedrooms','pop']]

# %%
y = df1[['Price']]

# %%
xnew = StandardScaler()
x1 = xnew.fit_transform(x)
scaled_df = pd.DataFrame(x1)
scaled_df
# Out:
#              0         1         2         3         4
# 0     1.028660 -0.296927  0.021274  0.088062 -1.317599
# 1     1.000808  0.025902 -0.255506 -0.722301  0.403999
# 2    -0.684629 -0.112303  1.516243  0.930840  0.072410
# 3    -0.491499  1.221572 -1.393077 -0.584540 -0.186734
# 4    -0.807073 -0.944834  0.846742  0.201513 -0.988387
# ...        ...       ...       ...       ...       ...
# 4995 -0.752109  1.869297 -0.845588 -0.422467 -1.342732
# 4996  0.929740  1.030822 -0.408686  0.031337 -1.062747
# 4997 -0.487235  1.284470 -2.170269 -1.500251 -0.291937
# 4998 -0.054592 -0.446694  0.141541  1.182053  0.651116
# 4999 -0.288313  0.015215 -0.194342  0.071855  1.041625
#
# [5000 rows x 5 columns]

# %%
yz = pd.DataFrame(y)
xnew1 = StandardScaler()
scaled_y = xnew1.fit_transform(yz)
scaled_df1 = pd.DataFrame(scaled_y)
scaled_df1
# Out:
#              0
# 0    -0.490081
# 1     0.775508
# 2    -0.490211
# 3     0.080843
# 4    -1.702518
# ...        ...
# 4995 -0.486795
# 4996  0.709594
# 4997 -0.570244
# 4998 -0.094640
# 4999  0.189411
#
# [5000 rows x 1 columns]

# %%
df2.corr()
# Out:
#              income  house_Age  no_rooms  bedrooms       pop     Price
# income     1.000000  -0.003564 -0.018594  0.014008 -0.007604  0.601308
# house_Age -0.003564   1.000000 -0.004599  0.006770 -0.005963  0.422227
# no_rooms  -0.018594  -0.004599  1.000000  0.475557  0.005144  0.304028
# bedrooms   0.014008   0.006770  0.475557  1.000000 -0.024550  0.152592
# pop       -0.007604  -0.005963  0.005144 -0.024550  1.000000  0.379448
# Price      0.601308   0.422227  0.304028  0.152592  0.379448  1.000000

# %%
sns.heatmap(df2.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
h = LabelEncoder()

# %%
df['Address'] = h.fit_transform(df['Address'])

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  Address
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,scaled_y,test_size=0.32,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
r = LinearRegression()

# %%
r.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = r.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9162129083819164

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
kf = KFold(n_splits = 5,shuffle =True,random_state = 42)

# %%
scores = cross_val_score(r,x1,scaled_y,cv=kf,scoring='accuracy')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:1006: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 137, in __call__
#     score = scorer._score(
#             ^^^^^^^^^^^^^^
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
print(scores)
# Out:
# [nan nan nan nan nan]
